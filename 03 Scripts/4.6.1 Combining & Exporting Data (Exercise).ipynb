# %% [markdown]
# **Contents**
#
# 01 Importing Libraries
#
# 02 Data Check: Order_products__prior.csv
#
# 03 Data Check: Orders_wrangled.csv
#
# 04 Data Merge
#
# 05 Export

# %% [markdown]
# # 01. Importing Libraries

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
# Set Path
path = r'C:\Users\Forrest\Desktop\Work\CareerFoundry\Python\2022-10 Instacart Basket Analysis'

# %% [markdown]
# # 02. Data check: Order_products__prior.csv

# %%
# Import prior orders df
df_ords_prior = pd.read_csv(os.path.join(path, '02 Data', 'Raw Data', 'order_products__prior.csv'), index_col = False)

# %%
# Check df_ords_prior
df_ords_prior.head(10)
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0
# 5         2       17794                  6          1
# 6         2       40141                  7          1
# 7         2        1819                  8          1
# 8         2       43668                  9          0
# 9         3       33754                  1          1

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %% [markdown]
# # 03. Data check: orders_wrangled.csv

# %%
# Import cleaned orders df
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_wrangled.csv'), index_col = 0)

# %%
# Check df_ords
df_ords.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
# 5   3367565        1             6                   2                  7
# 6    550135        1             7                   1                  9
# 7   3108588        1             8                   1                 14
# 8   2295261        1             9                   1                 16
# 9   2550362        1            10                   4                  8
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# ...

# %%
df_ords.shape
# Out:
# (3421083, 6)

# %% [markdown]
# # 04. Data merge

# %%
# Merging df_ords and df_ords_prior by order_id
df_merged_large = df_ords.merge(df_ords_prior, on = 'order_id', indicator = True)

# %%
# Checking merged df
df_merged_large.head(10)
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
# 5   2398795        1             2                   3                  7
# 6   2398795        1             2                   3                  7
# 7   2398795        1             2                   3                  7
# 8   2398795        1             2                   3                  7
# 9   2398795        1             2                   3                  7
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# ...

# %%
# Checking merged df shape
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# left_only            0
# right_only           0
# Name: _merge, dtype: int64

# %% [markdown]
# # 05. Export

# %%
# Exporting merged df
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined.pkl'))
